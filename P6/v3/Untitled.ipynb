# %%
import pandas as pd

# %%
ainfo = pd.read_csv("airports.dat", index_col='id')
ainfo
# Out:
#                                    name                city           country  \
# id
# 1                                Goroka              Goroka  Papua New Guinea
# 2                                Madang              Madang  Papua New Guinea
# 3                           Mount Hagen         Mount Hagen  Papua New Guinea
# 4                                Nadzab              Nadzab  Papua New Guinea
# 5            Port Moresby Jacksons Intl        Port Moresby  Papua New Guinea
# 6                            Wewak Intl               Wewak  Papua New Guinea
# 7                            Narsarsuaq        Narssarssuaq         Greenland
# 8                                  Nuuk            Godthaab         Greenland
# 9                     Sondre Stromfjord         Sondrestrom         Greenland
# 10                       Thule Air Base               Thule         Greenland
# 11                             Akureyri            Akureyri           Iceland
# ...

# %%
delays = pd.read_csv("2008delays_air.csv")
delays
# Out:
#      Origin Dest    DepDelay    ArrDelay  LateAircraftDelay  SecurityDelay  \
# 0       ABE  ATL   11.524941   11.548503          10.821053       0.105263
# 1       ABE  BHM   11.000000   -3.000000                NaN            NaN
# 2       ABE  CLE   -2.425505    0.849558          17.432990       0.000000
# 3       ABE  CLT   -2.200000   -2.916849           3.203704       0.000000
# 4       ABE  CVG   -0.700820   -4.493827           0.000000       0.000000
# 5       ABE  DTW    5.788877    5.327835          23.493750       0.000000
# 6       ABE  JFK   16.666667   24.333333           0.000000       0.000000
# 7       ABE  LGA   92.777778  106.888889           0.000000       0.000000
# 8       ABE  ORD   18.071695   16.386176          18.972900       0.000000
# 9       ABE  PHL   23.000000   17.000000           0.000000       0.000000
# 10      ABI  DFW    6.880397    5.037490          14.322368       0.000000
# ...

# %%
#https://en.wikipedia.org/wiki/List_of_the_busiest_airports_in_the_United_States
airports = ['ATL', 'LAX', 'ORD', 'DFW', 'JFK', 'DEN', 'SFO',
            'CLT', 'LAS', 'PHX', 'IAH', 'MIA', 'SEA', 'EWR',
            'MCO', 'MSP', 'DTW', 'BOS', 'PHL', 'LGA']

# %%
for o in airports:
    for d in airports:
        print "{"
        print "\torigin: {"
        print "\t\tlatitude:{},".format(ainfo[ainfo.code == 'ATL']['lat'].values[0])
        print "\t\tlatitude:{}".format(ainfo[ainfo.code == 'ATL']['lng'].values[0])
        print "\t}"
        print "},"
# Out:
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# 		latitude:33.636719,
# 		latitude:-84.428067
# 	}
# },
# {
# 	origin: {
# ...
